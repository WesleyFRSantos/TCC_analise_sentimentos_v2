# %% [markdown]
# # 1 Introdução
#
# Primeiramente, vamos separar uma porcentagem do conjunto de treino para testar o modelo e poder ter uma métrica. O objetivo da v2 será atingir uma métrica melhor.

# %% [markdown]
# # 2 Libs

# %%
import pandas as pd

import nltk
from string import punctuation
from nltk import tokenize
import unidecode

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, balanced_accuracy_score

# %matplotlib inline
# import matplotlib.pyplot as plt
# import seaborn as sns

# %% [markdown]
# # 3 Carrega dataset e separa conjunto de teste

# %%
df_treino = pd.read_csv('tweets_treino.csv',sep=';')
df_treino.head()
# Out:
#                     id                                         tweet_text  \
# 0  1050785521201541121  @Laranjito76 A pessoa certa para isso seria o ...
# 1  1050785431955140608  @behin_d_curtain Para mim, é precisamente o co...
# 2  1050785401248645120  Vou fazer um video hoje... estou pensando em f...
# 3  1050785370982547461  aaaaaaaa amei tanto essas polaroids, nem sei e...
# 4  1050785368902131713  Valoriza o coração do menininho que vc tem. El...
#
#                        tweet_date  sentiment query_used
# 0  Fri Oct 12 16:29:25 +0000 2018          1         :)
# 1  Fri Oct 12 16:29:04 +0000 2018          1         :)
# 2  Fri Oct 12 16:28:56 +0000 2018          1         :)
# 3  Fri Oct 12 16:28:49 +0000 2018          1         :)
# 4  Fri Oct 12 16:28:49 +0000 2018          1         :)

# %%
df_treino.shape
# Out:
# (100000, 5)

# %%
df_teste = df_treino.sample(frac=.1,random_state=42)
df_teste.head()
# Out:
#                         id                                         tweet_text  \
# 75721  1045103224259325952  Casagrande fala de esporte e política: 'O fute...
# 80184  1042126369130463232  Juízes distantes dos tribunais de origem https...
# 19864  1046797258392571904                @mynameiskb24 Ah ! Lucas content :)
# 76699  1044579206720618496  Claudia Leitte faz campanha de suplemento para...
# 92991  1039121256816226304  Uma semana cheia de boas atitudes! 🥇 #motivaçã...
#
#                            tweet_date  sentiment     query_used
# 75721  Thu Sep 27 00:10:00 +0000 2018          2        estadao
# 80184  Tue Sep 18 19:01:02 +0000 2018          2          folha
# 19864  Mon Oct 01 16:21:29 +0000 2018          1             :)
# 76699  Tue Sep 25 13:27:44 +0000 2018          2          exame
# 92991  Mon Sep 10 11:59:48 +0000 2018          2  #oportunidade

# %%
df_teste.shape
# Out:
# (10000, 5)

# %%
df_treino = df_treino.drop(df_teste.index)
df_treino.shape
# Out:
# (90000, 5)

# %% [markdown]
# # 4 Tratamento

# %% [markdown]
# ## 4.1 Cria coluna de classificação

# %%
df_treino = df_treino.dropna(subset=['tweet_text', 'sentiment'])

# %%
df_treino = df_treino[['tweet_text', 'tweet_date', 'sentiment']]

# %%
df_treino['sentiment'].value_counts()
# Out:
# 2    30033
# 0    30019
# 1    29948
# Name: sentiment, dtype: int64

# %%
df_treino['classificacao'] = df_treino['sentiment'].apply(lambda x : 'Positivo' if x == 1 else 'Neutro' if x == 2 else 'Negativo')

# %%
df_teste = df_teste.dropna(subset=['tweet_text','sentiment'])

# %%
df_teste = df_teste[['tweet_text', 'tweet_date', 'sentiment']]

# %%
df_teste['classificacao'] = df_teste['sentiment'].apply(lambda x : 'Positivo' if x == 1 else 'Neutro' if x == 2 else 'Negativo')

# %%
df_treino.head()
# Out:
#                                           tweet_text  \
# 0  @Laranjito76 A pessoa certa para isso seria o ...
# 1  @behin_d_curtain Para mim, é precisamente o co...
# 2  Vou fazer um video hoje... estou pensando em f...
# 3  aaaaaaaa amei tanto essas polaroids, nem sei e...
# 4  Valoriza o coração do menininho que vc tem. El...
#
#                        tweet_date  sentiment classificacao
# 0  Fri Oct 12 16:29:25 +0000 2018          1      Positivo
# 1  Fri Oct 12 16:29:04 +0000 2018          1      Positivo
# 2  Fri Oct 12 16:28:56 +0000 2018          1      Positivo
# 3  Fri Oct 12 16:28:49 +0000 2018          1      Positivo
# 4  Fri Oct 12 16:28:49 +0000 2018          1      Positivo

# %%
df_teste.head()
# Out:
#                                               tweet_text  \
# 75721  Casagrande fala de esporte e política: 'O fute...
# 80184  Juízes distantes dos tribunais de origem https...
# 19864                @mynameiskb24 Ah ! Lucas content :)
# 76699  Claudia Leitte faz campanha de suplemento para...
# 92991  Uma semana cheia de boas atitudes! 🥇 #motivaçã...
#
#                            tweet_date  sentiment classificacao
# 75721  Thu Sep 27 00:10:00 +0000 2018          2        Neutro
# 80184  Tue Sep 18 19:01:02 +0000 2018          2        Neutro
# 19864  Mon Oct 01 16:21:29 +0000 2018          1      Positivo
# 76699  Tue Sep 25 13:27:44 +0000 2018          2        Neutro
# 92991  Mon Sep 10 11:59:48 +0000 2018          2        Neutro

# %% [markdown]
# # 5 Processamento do texto
#
# Principais funções:
#
# 1) Stopwords - elimina palavras irrelevantes para a análise semântica (e, ou, a, o, as, os).
# 2) Punctuation - elimina pontos e símbolos (.'!"*&$%).
# 3) Tokenizer - quebra o texto em 'tokens' (partes), para que possa ser compreendido palavra por palavra.
# 4) Unidecode - retira os acentos.
# 5) Lower - deixa todas as letras em minúsculo.
# 6) Stemmer - utiliza somente os radicais das palavras, facilitando a interpretação de uma palavra que tenha o mesmo valor semântico, mesmo que em diferentes tempos verbais, gêneros ou número.

# %%
def tratar(df, coluna):

  palavras_irrelevantes = nltk.corpus.stopwords.words("portuguese")
  pontuacao = []
  for ponto in punctuation:
    pontuacao.append(ponto)
  pontuacao_stopwords = pontuacao + palavras_irrelevantes
  token_pontuacao = tokenize.WordPunctTokenizer()
  sem_acentos = [unidecode.unidecode(texto) for texto in df[coluna]]
  stopwords_sem_acentos = [unidecode.unidecode(texto) for texto in pontuacao_stopwords]
  stemmer = nltk.RSLPStemmer()

  df['texto_tratado'] = sem_acentos

  frase_processada = []

  for texto in df['texto_tratado']:
    
    nova_frase = []
    texto = texto.lower()
    texto = texto.replace('rt ','')
    texto = texto.replace('http','')
    texto = texto.replace('...','')
    texto = texto.replace('://','')
    texto = texto.replace('..','')
    palavras_texto = token_pontuacao.tokenize(texto)
    for palavra in palavras_texto:
        if palavra not in pontuacao_stopwords:
            nova_frase.append(stemmer.stem(palavra))
    frase_processada.append(' '.join(nova_frase))

  df['texto_tratado'] = frase_processada

# %%
tratar(df_treino,'tweet_text')

# %%
tratar(df_teste,'tweet_text')

# %%
df_treino.sample(5)
# Out:
#                                               tweet_text  \
# 47850      @XXKWY o meu pc quebrou :( não tenho mais lol
# 67943  Líderes, PT e PSDB perdem mais de 30% dos voto...
# 14158                           @ccIncredible de nada :)
# 23000  @ap_fernandes @marimessias @modices @manubarem...
# 893    ✨ PROMOÇÃO: COMBINADOS | O Pico Espeto Bar ✨ 3...
#
#                            tweet_date  sentiment classificacao  \
# 47850  Tue Oct 02 03:27:53 +0000 2018          0      Negativo
# 67943  Wed Oct 10 11:08:33 +0000 2018          2        Neutro
# 14158  Wed Oct 03 14:53:19 +0000 2018          1      Positivo
# 23000  Mon Oct 01 11:41:34 +0000 2018          1      Positivo
# 893    Fri Oct 12 15:00:06 +0000 2018          1      Positivo
#
#                                            texto_tratado
# 47850                          xxkwy pc quebr :( nao lol
# 67943  lid pt psdb perd 30 vot sen psl disp fic 3o lu...
# 14158                                 ccincredibl nad :)
# 23000  ap_fernand marimess modic manub jaridarra gost...
# 893    promoca combin pic espet bar 3 espet 1 cervej ...

# %%
df_teste.sample(5)
# Out:
#                                               tweet_text  \
# 91237  Semana Nacional do Trânsito. Educação e Consci...
# 92908  Isso sem contar as estrelas que formam o logo ...
# 56838  vou sentir tanta saudade :( #MPN #JoaoGuilherm...
# 4145   Espero que gostem de câmeras, pois ele quer ed...
# 28486           @mthware eu queria fazer o meu almoço :)
#
#                            tweet_date  sentiment classificacao  \
# 91237  Tue Sep 18 11:27:40 +0000 2018          2        Neutro
# 92908  Mon Sep 10 16:05:08 +0000 2018          2        Neutro
# 56838  Mon Oct 01 15:21:54 +0000 2018          0      Negativo
# 4145   Mon Oct 08 13:27:21 +0000 2018          1      Positivo
# 28486  Thu Sep 27 21:08:07 +0000 2018          1      Positivo
#
#                                            texto_tratado
# 91237  seman nacion transit educaca conscientizaca jo...
# 92908  cont estrel form log rockst carr fantasm pe gr...
# 56838  vou sent tant saudad :( mpn joaoguilherm st co...
# 4145   esper gost cam poi qu educaca distanc :) st co...
# 28486                             mthw quer faz almoc :)

# %% [markdown]
# # 6 Teste

# %%
regressao_logistica = LogisticRegression()

# %%
def classificar(df, texto, sentimento, df_teste, texto_teste):
  tfidf = TfidfVectorizer(lowercase=False,ngram_range=(1,2))

  treino_tfidf = tfidf.fit_transform(df[texto])
  teste_tfidf = tfidf.transform(df_teste[texto_teste]).todense()

  treino = treino_tfidf
  classe_treino = df[sentimento]
  teste = teste_tfidf

  regressao_logistica.fit(treino,classe_treino)

  classificacao = regressao_logistica.predict(teste)

  df_teste['sentimento'] = classificacao

# %%
df_teste
# Out:
#                                               tweet_text  \
# 75721  Casagrande fala de esporte e política: 'O fute...
# 80184  Juízes distantes dos tribunais de origem https...
# 19864                @mynameiskb24 Ah ! Lucas content :)
# 76699  Claudia Leitte faz campanha de suplemento para...
# 92991  Uma semana cheia de boas atitudes! 🥇 #motivaçã...
# ...                                                  ...
# 5002   @lopes85 @_Goalpoint "gentes" do benfiquistão ...
# 30151  @DeFerrazdede @srta_quitete @xquadrado @BrunoT...
# 93194  Vaga para Técnico de Enfermagem do Trabalho, e...
# 73199  &gt;@EstadaoPolitica Neutro no 1º turno, PSB v...
# 74479  Rejeição de Bolsonaro sobe de 43% para 46% e d...
#
#                            tweet_date  sentiment classificacao  \
# 75721  Thu Sep 27 00:10:00 +0000 2018          2        Neutro
# 80184  Tue Sep 18 19:01:02 +0000 2018          2        Neutro
# 19864  Mon Oct 01 16:21:29 +0000 2018          1      Positivo
# 76699  Tue Sep 25 13:27:44 +0000 2018          2        Neutro
# 92991  Mon Sep 10 11:59:48 +0000 2018          2        Neutro
# ...                               ...        ...           ...
# 5002   Mon Oct 08 11:52:35 +0000 2018          1      Positivo
# 30151  Thu Sep 27 19:18:55 +0000 2018          1      Positivo
# 93194  Sun Sep 09 01:40:45 +0000 2018          2        Neutro
# 73199  Mon Oct 01 22:40:00 +0000 2018          2        Neutro
# 74479  Sat Sep 29 00:16:30 +0000 2018          2        Neutro
#
#                                            texto_tratado
# 75721  casagrand fal esport poli futebol fic egoist c...
# 80184             juiz dist tribun orig st co ar9rh8f8e4
# 19864                     mynameiskb24 ah luc content :)
# 76699  claud leitt faz campanh suplement intoleranc l...
# 92991  seman chei boa atitud motivaca sucess oportun ...
# ...                                                  ...
# 5002   lopes85 _goalpoint gent benfiquista nao gost f...
# 30151  deferrazded srta_quitet xquadr brunotdd aosnet...
# 93194  vag tecn enferm trabalh farroupilh rs sucess v...
# 73199  gt ;@ estadaopoli neutr 1o turn psb vai posic ...
# 74479  rejeica bolsonar sob 43 46 haddad 29 32 %, mos...
#
# [10000 rows x 5 columns]

# %%
classificar(df_treino, 'texto_tratado', 'classificacao', df_teste, 'texto_tratado')
# Out:
# c:\Users\Wesley Ribeiro\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
df_treino
# Out:
#                                               tweet_text  \
# 0      @Laranjito76 A pessoa certa para isso seria o ...
# 1      @behin_d_curtain Para mim, é precisamente o co...
# 2      Vou fazer um video hoje... estou pensando em f...
# 3      aaaaaaaa amei tanto essas polaroids, nem sei e...
# 4      Valoriza o coração do menininho que vc tem. El...
# ...                                                  ...
# 99995  Confira esta vaga na Senac-RS: Editor De Video...
# 99996  Confira esta vaga na Grupo SABEMI: Assistente ...
# 99997  Confira esta vaga na Groupe L’OCCITANE: Gerent...
# 99998  Está no ar o CandidatoWEB, seu novo portal de ...
# 99999  Anavitória industrializa pop folk em álbum pau...
#
#                            tweet_date  sentiment classificacao  \
# 0      Fri Oct 12 16:29:25 +0000 2018          1      Positivo
# 1      Fri Oct 12 16:29:04 +0000 2018          1      Positivo
# 2      Fri Oct 12 16:28:56 +0000 2018          1      Positivo
# 3      Fri Oct 12 16:28:49 +0000 2018          1      Positivo
# 4      Fri Oct 12 16:28:49 +0000 2018          1      Positivo
# ...                               ...        ...           ...
# 99995  Fri Aug 17 14:57:05 +0000 2018          2        Neutro
# 99996  Fri Aug 17 14:55:26 +0000 2018          2        Neutro
# 99997  Fri Aug 17 14:52:48 +0000 2018          2        Neutro
# 99998  Fri Aug 17 14:50:33 +0000 2018          2        Neutro
# 99999  Thu Aug 09 01:59:00 +0000 2018          2        Neutro
#
#                                            texto_tratado
# 0                   laranjito76 pesso cert val azeved :)
# 1      behin_d_curtain mim precis contrari :) vem chu...
# 2      vou faz vide hoj pens fal pouc sobr nov met cs...
# 3      aaaaaaa ame tant polaroid sei express quant to...
# 4      valoriz coraca menin vc difer fac sorr ter cer...
# ...                                                  ...
# 99995  conf vag senac rs edit vide port alegr rs suce...
# 99996  conf vag grup sabem assist administraca pessoa...
# 99997  conf vag group l occitan gerent distrit sul po...
# 99998  ar candidatoweb nov port busc vag empreg vagas...
# 99999  anavit industrializ pop folk album paut explor...
#
# [90000 rows x 5 columns]

# %%
df_teste
# Out:
#                                               tweet_text  \
# 75721  Casagrande fala de esporte e política: 'O fute...
# 80184  Juízes distantes dos tribunais de origem https...
# 19864                @mynameiskb24 Ah ! Lucas content :)
# 76699  Claudia Leitte faz campanha de suplemento para...
# 92991  Uma semana cheia de boas atitudes! 🥇 #motivaçã...
# ...                                                  ...
# 5002   @lopes85 @_Goalpoint "gentes" do benfiquistão ...
# 30151  @DeFerrazdede @srta_quitete @xquadrado @BrunoT...
# 93194  Vaga para Técnico de Enfermagem do Trabalho, e...
# 73199  &gt;@EstadaoPolitica Neutro no 1º turno, PSB v...
# 74479  Rejeição de Bolsonaro sobe de 43% para 46% e d...
#
#                            tweet_date  sentiment classificacao  \
# 75721  Thu Sep 27 00:10:00 +0000 2018          2        Neutro
# 80184  Tue Sep 18 19:01:02 +0000 2018          2        Neutro
# 19864  Mon Oct 01 16:21:29 +0000 2018          1      Positivo
# 76699  Tue Sep 25 13:27:44 +0000 2018          2        Neutro
# 92991  Mon Sep 10 11:59:48 +0000 2018          2        Neutro
# ...                               ...        ...           ...
# 5002   Mon Oct 08 11:52:35 +0000 2018          1      Positivo
# 30151  Thu Sep 27 19:18:55 +0000 2018          1      Positivo
# 93194  Sun Sep 09 01:40:45 +0000 2018          2        Neutro
# 73199  Mon Oct 01 22:40:00 +0000 2018          2        Neutro
# 74479  Sat Sep 29 00:16:30 +0000 2018          2        Neutro
#
#                                            texto_tratado sentimento
# 75721  casagrand fal esport poli futebol fic egoist c...     Neutro
# 80184             juiz dist tribun orig st co ar9rh8f8e4     Neutro
# 19864                     mynameiskb24 ah luc content :)   Negativo
# 76699  claud leitt faz campanh suplement intoleranc l...     Neutro
# 92991  seman chei boa atitud motivaca sucess oportun ...     Neutro
# ...                                                  ...        ...
# 5002   lopes85 _goalpoint gent benfiquista nao gost f...   Positivo
# 30151  deferrazded srta_quitet xquadr brunotdd aosnet...   Positivo
# 93194  vag tecn enferm trabalh farroupilh rs sucess v...     Neutro
# 73199  gt ;@ estadaopoli neutr 1o turn psb vai posic ...     Neutro
# 74479  rejeica bolsonar sob 43 46 haddad 29 32 %, mos...     Neutro
#
# [10000 rows x 6 columns]

# %%
df_teste['validacao'] = df_teste['classificacao'] == df_teste['sentimento']
df_teste['validacao'] = df_teste['validacao'].astype(int)
df_teste
# Out:
#                                               tweet_text  \
# 75721  Casagrande fala de esporte e política: 'O fute...
# 80184  Juízes distantes dos tribunais de origem https...
# 19864                @mynameiskb24 Ah ! Lucas content :)
# 76699  Claudia Leitte faz campanha de suplemento para...
# 92991  Uma semana cheia de boas atitudes! 🥇 #motivaçã...
# ...                                                  ...
# 5002   @lopes85 @_Goalpoint "gentes" do benfiquistão ...
# 30151  @DeFerrazdede @srta_quitete @xquadrado @BrunoT...
# 93194  Vaga para Técnico de Enfermagem do Trabalho, e...
# 73199  &gt;@EstadaoPolitica Neutro no 1º turno, PSB v...
# 74479  Rejeição de Bolsonaro sobe de 43% para 46% e d...
#
#                            tweet_date  sentiment classificacao  \
# 75721  Thu Sep 27 00:10:00 +0000 2018          2        Neutro
# 80184  Tue Sep 18 19:01:02 +0000 2018          2        Neutro
# 19864  Mon Oct 01 16:21:29 +0000 2018          1      Positivo
# 76699  Tue Sep 25 13:27:44 +0000 2018          2        Neutro
# 92991  Mon Sep 10 11:59:48 +0000 2018          2        Neutro
# ...                               ...        ...           ...
# 5002   Mon Oct 08 11:52:35 +0000 2018          1      Positivo
# 30151  Thu Sep 27 19:18:55 +0000 2018          1      Positivo
# 93194  Sun Sep 09 01:40:45 +0000 2018          2        Neutro
# 73199  Mon Oct 01 22:40:00 +0000 2018          2        Neutro
# 74479  Sat Sep 29 00:16:30 +0000 2018          2        Neutro
#
#                                            texto_tratado sentimento  validacao
# 75721  casagrand fal esport poli futebol fic egoist c...     Neutro          1
# 80184             juiz dist tribun orig st co ar9rh8f8e4     Neutro          1
# 19864                     mynameiskb24 ah luc content :)   Negativo          0
# 76699  claud leitt faz campanh suplement intoleranc l...     Neutro          1
# 92991  seman chei boa atitud motivaca sucess oportun ...     Neutro          1
# ...                                                  ...        ...        ...
# 5002   lopes85 _goalpoint gent benfiquista nao gost f...   Positivo          1
# 30151  deferrazded srta_quitet xquadr brunotdd aosnet...   Positivo          1
# 93194  vag tecn enferm trabalh farroupilh rs sucess v...     Neutro          1
# 73199  gt ;@ estadaopoli neutr 1o turn psb vai posic ...     Neutro          1
# 74479  rejeica bolsonar sob 43 46 haddad 29 32 %, mos...     Neutro          1
#
# [10000 rows x 7 columns]

# %%
len(df_teste[df_teste['validacao']==1])
# Out:
# 8026

# %%
accuracy = accuracy_score(df_teste['classificacao'], df_teste['sentimento'])
accuracy
# Out:
# 0.8026

# %%
b_accuracy = balanced_accuracy_score(df_teste['classificacao'], df_teste['sentimento'])
b_accuracy
# Out:
# 0.8036604018210127
